# %%
import pandas as pd
from newspaper import Article
import nltk

articles = pd.read_csv('newsArticlesWithLabels.tsv', sep='\t')

democrat_opinion = articles.loc[:, "democrat.vote"]

republican_opinion = articles.loc[:, "republican.vote"]

article_url = articles.loc[:, "url"]

democrat_num = []
republican_num = []
def numberSetter(dataframe, array):
    for i in dataframe:
        if(i == "Positive"):
            array.append(1)
        
        if(i == "SomewhatPositive"):
            array.append(0.5)
        
        if(i == "Negative"):
            array.append(1)
        
        if(i == "SomewhatNegative"):
            array.append(-0.5)
        
        if(i == "Neutral"):
            array.append(-1)
    return array
        

    
democrat_num = numberSetter(democrat_opinion, democrat_num)
republican_num = numberSetter(republican_opinion, republican_num)

#adding article urls to designated files
# d = open("Democrat.txt", "a")
# r = open("Republican.txt", "a")
# for i in range(articles.shape[0]):
#     if(democrat_num[i]-republican_num[i]>0):
#         d.write(article_url[i] + "\n")
        
#     else:
#         r.write(article_url[i] + "\n")
        
# d.close()
# r.close()
# len(democrat_num)
# len(republican_num)
# r = open("republican.txt", "a")
# r.write("\n")
# r.close()

# r = open("democrat.txt", "a")
# r.write("\n")
# r.close()

# %%
articles.loc[:,"q3"]
articles
# Out:
#                                                      url       q3  perceived  \
# 0      http://www.usatoday.com/story/news/nation/2013...    other          1
# 1      http://www.huffingtonpost.com/2013/05/21/senat...     News          0
# 2      http://www.washingtonpost.com/opinions/dont-le...  Opinion          1
# 3      http://www.foxnews.com/politics/2013/04/03/oba...  Opinion          1
# 4      http://www.breitbart.com/Big-Government/2013/1...  Opinion          1
# ...                                                  ...      ...        ...
# 20999  http://www.washingtonpost.com/opinions/dana-mi...     News          1
# 21000  http://news.yahoo.com/republicans-hatred-obama...  Opinion          1
# 21001  http://www.washingtonpost.com/opinions/dana-mi...     News          1
# 21002  http://www.washingtonpost.com/opinions/ej-dion...     News          1
# 21003  http://www.huffingtonpost.com/2013/08/11/this-...  Opinion          1
#
# ...
